# %%
import pandas as pd

from email_outreach.experiment_utils.metric_loader import load_experiment_metrics
from email_outreach.ml.shallow_autoencoder.abstract_contextual_model import AbstractContextualModel
from email_outreach.utils.constants import ROOT_FOLDER
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt

# %%
def get_precisions_recalls(path: Path, quantiles=1 - np.linspace(start=0, stop=1, num=100)):
    experiments: list[list] = load_experiment_metrics(path)
    recalls: list[float] = []
    precisions: list[float] = []
    for experiment in experiments:
        recall, precision = AbstractContextualModel.calculate_recall_precision_at_quantiles(experiment,
                                                                                            quantiles=quantiles)[1:3]

        recalls.append(recall)
        precisions.append(precision)

    return recalls, precisions

# %%
revised_s: Path = ROOT_FOLDER / "experiments" / "test_set" / "1" / "contextual_bandit" / "revised_s_revised_f_v2"
baseline: Path = ROOT_FOLDER / "experiments" / "test_set" / "1" / "contextual_bandit" / "baseline_v2"
non_naive_f: Path = ROOT_FOLDER / "experiments" / "test_set" / "1" / "contextual_bandit" / "non_naive_f_v2"

# %%
baseline_recalls, baseline_precisions = get_precisions_recalls(baseline)
revised_s_recalls, revised_s_precisions = get_precisions_recalls(revised_s)
non_naive_f_recalls, non_naive_f_precisions = get_precisions_recalls(non_naive_f)

# %%
print(f"Baseline recall: {np.array(baseline_recalls).mean(axis=0)}")
print(f"Revised s recall: {np.array(revised_s_recalls).mean(axis=0)}")
print(f"Non-naive f recall: {np.array(non_naive_f_recalls).mean(axis=0)}")
# Out:
# Baseline recall: [3.12075052e-05 3.09546501e-02 1.27430414e-01 2.24620259e-01
#  3.10711362e-01 3.84651217e-01 4.48944917e-01 5.03436012e-01
#  5.53600796e-01 6.06030703e-01 6.57547169e-01 7.03190888e-01
#  7.41921737e-01 7.74804656e-01 8.00482675e-01 8.21350049e-01
#  8.37900337e-01 8.51987032e-01 8.64264165e-01 8.75441498e-01
#  8.85209685e-01 8.93955572e-01 9.02118299e-01 9.09823641e-01
#  9.16743273e-01 9.23415361e-01 9.28908504e-01 9.33978552e-01
#  9.38015179e-01 9.41959181e-01 9.45461534e-01 9.48885132e-01
#  9.51784757e-01 9.54099198e-01 9.56051271e-01 9.58026808e-01
#  9.60086029e-01 9.61904085e-01 9.63673826e-01 9.65015782e-01
#  9.66433119e-01 9.67556939e-01 9.68657939e-01 9.69598676e-01
#  9.70360089e-01 9.71071515e-01 9.71852127e-01 9.72641866e-01
#  9.73290874e-01 9.74257364e-01 9.74934795e-01 9.75679848e-01
#  9.76271123e-01 9.76934231e-01 9.77525815e-01 9.78155392e-01
#  9.78827136e-01 9.79450759e-01 9.79971293e-01 9.80425002e-01
#  9.80963221e-01 9.81384816e-01 9.81975128e-01 9.82452377e-01
#  9.83043770e-01 9.83573655e-01 9.84027040e-01 9.84664687e-01
#  9.85283351e-01 9.85871484e-01 9.86379073e-01 9.86880860e-01
#  9.87339585e-01 9.87793833e-01 9.88152756e-01 9.88700235e-01
#  9.89066232e-01 9.89566318e-01 9.89988514e-01 9.90459688e-01
#  9.91097494e-01 9.91648359e-01 9.92102640e-01 9.92647160e-01
#  9.93012732e-01 9.93496019e-01 9.93896885e-01 9.94471276e-01
#  9.94849114e-01 9.95334860e-01 9.95852669e-01 9.96538089e-01
#  9.97036127e-01 9.97427916e-01 9.97972079e-01 9.98378696e-01
#  9.98748146e-01 9.99205929e-01 9.99626835e-01 1.00000000e+00]
# Revised s recall: [2.06178417e-04 1.33182056e-01 1.96174661e-01 2.55550749e-01
#  3.15673167e-01 3.76470951e-01 4.39803711e-01 5.00766529e-01
#  5.55441564e-01 6.07813755e-01 6.58633306e-01 7.04082513e-01
#  7.43894795e-01 7.80153892e-01 8.09216163e-01 8.31110029e-01
#  8.49122219e-01 8.64372066e-01 8.77765016e-01 8.88962860e-01
#  8.98269183e-01 9.06863023e-01 9.14747199e-01 9.22274337e-01
#  9.29280226e-01 9.35552400e-01 9.41233636e-01 9.45805612e-01
#  9.50006603e-01 9.53390431e-01 9.56483662e-01 9.58848024e-01
#  9.60943524e-01 9.62329697e-01 9.63815963e-01 9.64999057e-01
#  9.65902103e-01 9.66846532e-01 9.67571895e-01 9.68348466e-01
#  9.69156592e-01 9.69787675e-01 9.70456424e-01 9.71080407e-01
#  9.71700576e-01 9.72337639e-01 9.73014451e-01 9.73618697e-01
#  9.74188631e-01 9.74769839e-01 9.75280709e-01 9.75979640e-01
#  9.76530062e-01 9.77204295e-01 9.77836091e-01 9.78513754e-01
#  9.79173960e-01 9.79722989e-01 9.80304386e-01 9.80851356e-01
#  9.81465361e-01 9.81962932e-01 9.82495051e-01 9.83006345e-01
#  9.83631329e-01 9.84231936e-01 9.84798440e-01 9.85299266e-01
#  9.85719103e-01 9.86181041e-01 9.86773657e-01 9.87310708e-01
#  9.87807756e-01 9.88245373e-01 9.88718083e-01 9.89294432e-01
#  9.89784422e-01 9.90292513e-01 9.90817620e-01 9.91294293e-01
#  9.91766442e-01 9.92197551e-01 9.92679825e-01 9.93118328e-01
#  9.93562578e-01 9.94101038e-01 9.94592353e-01 9.94981315e-01
#  9.95515930e-01 9.95992002e-01 9.96381574e-01 9.96866337e-01
#  9.97403990e-01 9.97731373e-01 9.98228199e-01 9.98741027e-01
#  9.99071709e-01 9.99291776e-01 9.99662095e-01 1.00000000e+00]
# Non-naive f recall: [1.70872840e-04 8.42097247e-02 1.39699746e-01 2.12973259e-01
#  2.92142172e-01 3.74860258e-01 4.55192346e-01 5.30399259e-01
#  5.97909791e-01 6.57168160e-01 7.06414292e-01 7.44763701e-01
#  7.75522413e-01 8.01654025e-01 8.23175630e-01 8.40835657e-01
#  8.55900656e-01 8.69316313e-01 8.80496666e-01 8.90793349e-01
#  9.00149625e-01 9.08702182e-01 9.16597896e-01 9.24263263e-01
#  9.31156570e-01 9.37143219e-01 9.42922186e-01 9.47612471e-01
#  9.51706389e-01 9.54862007e-01 9.57331026e-01 9.59889147e-01
#  9.61777956e-01 9.63335335e-01 9.64494870e-01 9.65685440e-01
#  9.66651302e-01 9.67507218e-01 9.68294682e-01 9.68863496e-01
#  9.69477400e-01 9.69984536e-01 9.70615227e-01 9.71343306e-01
#  9.72061328e-01 9.72673045e-01 9.73341198e-01 9.73854650e-01
#  9.74446978e-01 9.75107370e-01 9.75629050e-01 9.76146740e-01
#  9.76863239e-01 9.77492257e-01 9.77982781e-01 9.78518390e-01
#  9.79061918e-01 9.79570798e-01 9.80193090e-01 9.80690758e-01
#  9.81324850e-01 9.81815218e-01 9.82444555e-01 9.83074560e-01
#  9.83656167e-01 9.84104323e-01 9.84519758e-01 9.85020362e-01
#  9.85515141e-01 9.85939298e-01 9.86436573e-01 9.86874064e-01
#  9.87443643e-01 9.87931988e-01 9.88503068e-01 9.88995577e-01
#  9.89586257e-01 9.90066624e-01 9.90537696e-01 9.90983018e-01
#  9.91493002e-01 9.92024235e-01 9.92498548e-01 9.92918953e-01
#  9.93311393e-01 9.93864077e-01 9.94391932e-01 9.94848123e-01
#  9.95300171e-01 9.95769732e-01 9.96172382e-01 9.96704427e-01
#  9.97187980e-01 9.97542225e-01 9.97950995e-01 9.98311412e-01
#  9.98829247e-01 9.99283863e-01 9.99640899e-01 1.00000000e+00]

# %%
plt.figure(figsize=(15, 15))

plt.plot(np.linspace(start=0, stop=1, num=100), np.array(baseline_recalls).mean(axis=0), label="Baseline Recalls")
plt.plot(np.linspace(start=0, stop=1, num=100), np.array(revised_s_recalls).mean(axis=0),
         label="Revised S Recalls")

plt.plot(np.linspace(start=0, stop=1, num=100), np.array(non_naive_f_recalls).mean(axis=0),
         label="Non-Naive F Recalls")


plt.vlines(x=0.15, ymin=0, ymax=1)
plt.legend()
plt.show()
